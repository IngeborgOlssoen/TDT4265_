# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# (![DL Øving 1-1.jpg](<attachment:DL Øving 1-1.jpg>)) "Validation loss over traning")

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2b)
# Validation loss over traning
# ![alt text](![Skjermbilde 2024-02-09 kl. 16.56.02.png](<attachment:Skjermbilde 2024-02-09 kl. 16.56.02.png>) "Validation loss over traning")

# %% [markdown]
# ## Task 2c)
# Calculate accurracy(![Skjermbilde 2024-02-09 kl. 16.56.11.png](<attachment:Skjermbilde 2024-02-09 kl. 16.56.11.png>))

# %% [markdown]
# ## Task 2d)
# 515 steps

# %% [markdown]
# ## Task 2e)
# The presence or absence of shuffle affects the randomness and order of data presented to the model during training. Shuffling introduces more randomness and variability, potentially leading to larger fluctuations in the validation accuracy, while training without shuffle may result in smoother validation accuracy curves over epochs.
# ![](task2e_train_accuracy_shuffle_difference.png)

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Task 3b)
# ![](task3b_softmax_train_loss.png)

# %% [markdown]
# ## Task 3c)
# ![](task3b_softmax_train_accuracy.png)

# %% [markdown]
# ## Task 3d)
# FILL IN ANSWER

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# Fill in image of hand-written notes which are easy to read, or latex equations here
#
# ![DL Øving 1-2.jpg](<attachment:DL Øving 1-2.jpg>)

# %% [markdown]
# ## Task 4b)
# The L2 regularization term encourages the model to learn smoother weight vectors by penalizing large weights. As the value of λ increases, the regularization effect becomes stronger, leading to less noisy weights and better generalization performance on unseen data.
#
# ![](task4b_softmax_weight.png)

# %% [markdown]
# ## Task 4c)
# The x-axis represents the number of training steps, which is stored in the variable training_steps.
# The y-axis represents the validation accuracy.
# Each line plot corresponds to a different value of λ, and they are plotted on the same graph. The legend indicates which line corresponds to each λ value.
#
# ![](task4c_l2_reg_accuracy.png)

# %% [markdown]
# ## Task 4d)
#
# Tthe degradation of validation accuracy when applying regularization may stem from a combination of over-regularization, underfitting, information loss, bias-variance tradeoff, and improper hyperparameter tuning. It's crucial to carefully adjust the regularization strength and monitor the model's performance on the validation set to mitigate these effects and achieve optimal generalization.
#
# ![](task4d_l2_reg_norms.png)

# %% [markdown]
# ## Task 4e)
# By plotting the L2 norms for different λ values, you can observe how the regularization strength affects the magnitude of the weight vector after training. Typically, higher values of λ lead to smaller L2 norms due to stronger regularization.

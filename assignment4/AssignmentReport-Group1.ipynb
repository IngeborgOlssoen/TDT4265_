# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1 //6.25 poeng//

# %% [markdown]
# ## task 1a)
#
# ![4_1A.jpeg](attachment:4_1A.jpeg)

# %% [markdown]
# ## task 1b)
#
# ###True Positives (TP):
#
# These are the cases where the classifier correctly predicts the positive class. In other words, the instances that are actually positive and the classifier also predicts them as positive.
#
# ###False Positives (FP):
#
# These are the instances where the classifier incorrectly predicts the positive class. This means the classifier predicts positive, but the actual class is negative.
#
# ![4_1B.jpeg](attachment:4_1B.jpeg)
#
# ## task 1c)
#
# ![4_1C.jpeg](attachment:4_1C.jpeg)

# %% [markdown]
# # Task 2 //30.0 poeng//
#
# ### Task 2f)

# %% [markdown]
# # Task 3 //17.5 poeng//

# %% [markdown]
# ### Task 3a)
# The filter operation which filter out a set of overlapping boxes is called non-maximum suppression. It helps us to select the most appropirate bounding box for the object.
#
#
# ### Task 3b)
# True. This is because deeper layers in the network capture more abstract and high-level features, which are crucial for accurately detecting smaller objects with fewer visual cues.
#
# ### Task 3c)
# Using different bounding box aspect ratios at the same spatial location enables the SSD model to effectively detect objects of diverse shapes and sizes, leading to improved accuracy, coverage, and robustness in object detection tasks.
#
#
# ### Task 3d)
# Both SSD and YOLOv1/v2 are single-shot object detection systems, they differ in their architectural design, feature extraction methods, prediction strategies, and loss functions, which can impact their performance and suitability for different applications.
#
# ### Task 3e)
# We use this formula: Total number of anchor boxes = Number of anchor locations x Number of aspect ratios per location
#
# Total number of anchor locations is 38x38(HxW), and we place 6 different anchors with different aspect ratios at each anchor location.
# 38x38=1444
# Total number of anchor boxes = 1444(anchor locations)x6(aspect ratios) = 8664
#
# ### Task 3f)
# For 38x38:
# 38x38x6=8664
#
# For 19x19:
# 19x19x6=2166
#
# For 10x10:
# 10x10x6=600
#
# For 5x5:
# 5x5x6=150
#
# For 3x3:
# 3x3x6=54
#
# For 1x1:
# 1x1x6=6
#
# Total anchor boxes = 8664 + 2166 + 600 + 150 + 54 + 6 = 11540
# So, there are a total of 11540 anchor boxes for the entire network.

# %% [markdown]
# # Task 4 //46.25 poeng//

# %% [markdown]
# ## Task 4b)
#
# FILL IN ANSWER.
#
# ## Task 4c)
# FILL IN ANSWER.
#
#
# ## Task 4d)
# FILL IN ANSWER.
#
#
# ## Task 4e)
# FILL IN ANSWER.
#
#
# ## Task 4f)
# FILL IN ANSWER.
